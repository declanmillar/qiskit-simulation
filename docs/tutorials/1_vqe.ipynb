# %% [markdown]
# # Variational quantum eigensolver
#
# ## Background
#
# [Variational quantum algorithms](https://arxiv.org/abs/2012.09265) are promising candidate hybrid-algorithms for observing quantum computation utility on noisy near-term devices. Variational algorithms are characterized by the use of a classical optimization algorithm to iteratively update a parameterized trial solution, or "ansatz". Chief among these methods is the Variational Quantum Eigensolver (VQE) that aims to solve for the ground state of a given Hamiltonian represented as a linear combination of Pauli terms, with an ansatz circuit where the number of parameters to optimize over is polynomial in the number of qubits.  Given that the size of the full solution vector is exponential in the number of qubits, successful minimization using VQE requires, in general, additional problem-specific information to define the structure of the ansatz circuit.
#
# Executing a VQE algorithm requires the following components:
#
# 1. Hamiltonian and ansatz (problem specification)
# 2. Qiskit Runtime estimator
# 3. Classical optimizer
#
# Although the Hamiltonian and ansatz require domain-specific knowledge to construct, these details are immaterial to the Runtime, and we can execute a wide class of VQE problems in the same manner.

# %% [markdown]
# ## Setup
#
# Here we import the tools needed for a VQE experiment.

# %%
# General imports
import numpy as np

# Pre-defined ansatz circuit and operator class for Hamiltonian
from qiskit import QuantumCircuit
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp

# SciPy minimizer routine
from scipy.optimize import minimize

# Plotting functions
import matplotlib.pyplot as plt

# Qiskit primitive imports
from qiskit.primitives import BaseEstimatorV2, BackendEstimatorV2 as Estimator
from qiskit.providers.fake_provider import GenericBackendV2

# %% [markdown]
# ## Step 1: Map classical inputs to a quantum problem
#
# Although the problem instance in question for the VQE algorithm can come from a variety of domains, the form for execution through Qiskit Runtime is the same. Qiskit provides a convenience class for expressing Hamiltonians in Pauli form, and a collection of widely used ansatz circuits in the [`qiskit.circuit.library`](https://docs.quantum-computing.ibm.com/api/qiskit/circuit_library).
#
# This example Hamiltonian is derived from a quantum chemistry problem.

# %%
hamiltonian = SparsePauliOp.from_list(
    [("YZ", 0.3980), ("ZI", -0.3980), ("ZZ", -0.0113), ("XX", 0.1810)]
)

# %% [markdown]
# Our choice of ansatz is the `EfficientSU2` that, by default, linearly entangles qubits, making it ideal for quantum hardware with limited connectivity.

# %%
ansatz = EfficientSU2(hamiltonian.num_qubits)
ansatz.decompose().draw("mpl", style="iqp")

# %% [markdown]
# From the previous figure we see that our ansatz circuit is defined by a vector of parameters, $\theta_{i}$, with the total number given by:

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 16

# %% [markdown]
# ## Step 2: Optimize problem for quantum execution

# %% [markdown]
# To reduce the total job execution time, Qiskit primitives only accept circuits (ansatz) and observables (Hamiltonian) that conform to the instructions and connectivity supported by the target system (referred to as instruction set architecture (ISA) circuits and observables).

# %% [markdown]
# ### ISA circuit

# %% [markdown]
# Schedule a series of [`qiskit.transpiler`](https://docs.quantum-computing.ibm.com/api/qiskit/transpiler) passes to optimize the circuit for a selected backend and make it compatible with the backend's ISA. This can be easily done with a preset pass manager from `qiskit.transpiler` and its `optimization_level` parameter.
#
# The lowest optimization level does the minimum needed to get the circuit running on the device; it maps the circuit qubits to the device qubits and adds swap gates to allow all two-qubit operations. The highest optimization level is much smarter and uses lots of tricks to reduce the overall gate count. Since multi-qubit gates have high error rates and qubits decohere over time, the shorter circuits should give better results.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

backend = GenericBackendV2(hamiltonian.num_qubits)
target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(ansatz)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %% [markdown]
# ### ISA observable

# %% [markdown]
# Transform the Hamiltonian to make it backend-compatible before running jobs with [`Runtime Estimator V2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2#run). Perform the transformation by using the `apply_layout` method of `SparsePauliOp` object.

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit Primitives
#
# Like many classical optimization problems, the solution to a VQE problem can be formulated as minimization of a scalar cost function.  By definition, VQE looks to find the ground state solution to a Hamiltonian by optimizing the ansatz circuit parameters to minimize the expectation value (energy) of the Hamiltonian.  With the Qiskit Runtime [`Estimator`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2) directly taking a Hamiltonian and parameterized ansatz, and returning the necessary energy, the cost function for a VQE instance is quite simple.
#
# Note that the `run()` method of [Qiskit Runtime `EstimatorV2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2)  takes an iterable of `primitive unified blocs (PUBs)`. Each PUB is an iterable in the format `(circuit, observables, parameter_values: Optional, precision: Optional)`.

# %%
def cost_func(
    params: np.ndarray,
    ansatz: QuantumCircuit,
    hamiltonian: SparsePauliOp,
    estimator: BaseEstimatorV2,
    history: dict,
) -> float:
    """Return estimate of energy from estimator

    Parameters:
        params: Array of ansatz parameters.
        ansatz: Parameterized ansatz circuit.
        hamiltonian: Operator representation of Hamiltonian.
        estimator: Estimator primitive instance.
        history: Dictionary for storing intermediate results.

    Returns:
        Energy estimate.
    """
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    history["iters"] += 1
    history["prev_vector"] = params
    history["cost_history"].append(energy)
    print(f"Iters. done: {history['iters']} [Current cost: {energy}]")

    return energy

# %% [markdown]
# Also note that, in addition to the array of optimization parameters that must be the first argument, we use additional arguments to pass the terms needed in the cost function, such as the `cost_history_dict`. This dictionary stores the current vector at each iteration, for example in case you need to restart the routine due to failure, and also returns the current iteration number and average time per iteration.

# %%
history = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

# %% [markdown]
# We can now use a classical optimizer of our choice to minimize the cost function. Here, we use the [COBYLA routine from SciPy through the `minimize` function](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html). Note that when running on real quantum hardware, the choice of optimizer is important, as not all optimizers handle noisy cost function landscapes equally well.
#
# To begin the routine, specify a random initial set of parameters:

# %%
x0 = 2 * np.pi * np.random.random(num_params)

# %%
x0
# Out:
# array([2.54529723, 6.0703479 , 1.70060082, 0.42647393, 5.19821253,
#        2.3126183 , 1.86953101, 0.56542121, 4.99751824, 0.15819411,
#        0.63383893, 0.27893041, 0.96708058, 5.75355519, 5.13959773,
#        1.51010354])

# %% [markdown]
# Because we are sending a large number of jobs that we would like to execute together, we use a [`Session`](https://docs.quantum-computing.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.Session) to execute all the generated circuits in one block.  Here `args` is the standard SciPy way to supply the additional parameters needed by the cost function.

# %%
estimator = Estimator(backend=backend)
estimator.options.default_shots = 10000

res = minimize(
    cost_func,
    x0,
    args=(ansatz_isa, hamiltonian_isa, estimator, history),
    method="cobyla",
)
# Out:
# Iters. done: 1 [Current cost: -0.24798193359374998]
# Iters. done: 2 [Current cost: -0.40550410156250005]
# Iters. done: 3 [Current cost: -0.27770771484375]
# Iters. done: 4 [Current cost: -0.409981982421875]
# Iters. done: 5 [Current cost: -0.3548345703125]
# Iters. done: 6 [Current cost: -0.18940229492187502]
# Iters. done: 7 [Current cost: -0.377735009765625]
# Iters. done: 8 [Current cost: -0.4024959960937501]
# Iters. done: 9 [Current cost: -0.45931455078125]
# Iters. done: 10 [Current cost: -0.17787109375000004]
# Iters. done: 11 [Current cost: -0.034566308593750025]
# Iters. done: 12 [Current cost: -0.27300498046875]
# Iters. done: 13 [Current cost: -0.488393994140625]
# Iters. done: 14 [Current cost: -0.5241666992187499]
# Iters. done: 15 [Current cost: -0.313181640625]
# Iters. done: 16 [Current cost: -0.48011015625000003]
# Iters. done: 17 [Current cost: -0.57499521484375]
# Iters. done: 18 [Current cost: -0.32371704101562504]
# Iters. done: 19 [Current cost: -0.53007568359375]
# Iters. done: 20 [Current cost: -0.318680615234375]
# Iters. done: 21 [Current cost: -0.5414624023437501]
# Iters. done: 22 [Current cost: -0.37632407226562503]
# Iters. done: 23 [Current cost: -0.480513134765625]
# Iters. done: 24 [Current cost: -0.559066845703125]
# Iters. done: 25 [Current cost: -0.594070947265625]
# Iters. done: 26 [Current cost: -0.496235498046875]
# Iters. done: 27 [Current cost: -0.57504423828125]
# Iters. done: 28 [Current cost: -0.412328515625]
# Iters. done: 29 [Current cost: -0.54043955078125]
# Iters. done: 30 [Current cost: -0.5944083984375]
# Iters. done: 31 [Current cost: -0.5503107421875]
# Iters. done: 32 [Current cost: -0.5677736328125]
# Iters. done: 33 [Current cost: -0.5339621582031251]
# Iters. done: 34 [Current cost: -0.615382470703125]
# Iters. done: 35 [Current cost: -0.560560205078125]
# Iters. done: 36 [Current cost: -0.6123703125000001]
# Iters. done: 37 [Current cost: -0.529543017578125]
# Iters. done: 38 [Current cost: -0.61331162109375]
# Iters. done: 39 [Current cost: -0.59340703125]
# Iters. done: 40 [Current cost: -0.5959091796875]
# Iters. done: 41 [Current cost: -0.582316552734375]
# Iters. done: 42 [Current cost: -0.595466455078125]
# Iters. done: 43 [Current cost: -0.5752502441406251]
# Iters. done: 44 [Current cost: -0.6176135742187501]
# Iters. done: 45 [Current cost: -0.6072203125]
# Iters. done: 46 [Current cost: -0.6237169921875]
# Iters. done: 47 [Current cost: -0.614362255859375]
# Iters. done: 48 [Current cost: -0.6265025390625]
# Iters. done: 49 [Current cost: -0.6191006835937499]
# Iters. done: 50 [Current cost: -0.6066789550781249]
# Iters. done: 51 [Current cost: -0.6417262695312501]
# Iters. done: 52 [Current cost: -0.631130517578125]
# Iters. done: 53 [Current cost: -0.624853564453125]
# Iters. done: 54 [Current cost: -0.6454860351562501]
# Iters. done: 55 [Current cost: -0.65367802734375]
# Iters. done: 56 [Current cost: -0.617722314453125]
# Iters. done: 57 [Current cost: -0.6561021972656251]
# Iters. done: 58 [Current cost: -0.656970361328125]
# Iters. done: 59 [Current cost: -0.6475990234375]
# Iters. done: 60 [Current cost: -0.6419798339843751]
# Iters. done: 61 [Current cost: -0.661934619140625]
# Iters. done: 62 [Current cost: -0.6503912597656251]
# Iters. done: 63 [Current cost: -0.6400640624999999]
# Iters. done: 64 [Current cost: -0.6410219238281251]
# Iters. done: 65 [Current cost: -0.6470555175781251]
# Iters. done: 66 [Current cost: -0.64279580078125]
# Iters. done: 67 [Current cost: -0.651006298828125]
# Iters. done: 68 [Current cost: -0.648218310546875]
# Iters. done: 69 [Current cost: -0.6608283203125]
# Iters. done: 70 [Current cost: -0.6665504394531251]
# Iters. done: 71 [Current cost: -0.629197802734375]
# Iters. done: 72 [Current cost: -0.647759130859375]
# Iters. done: 73 [Current cost: -0.643619482421875]
# Iters. done: 74 [Current cost: -0.6443083984375001]
# Iters. done: 75 [Current cost: -0.6607217773437499]
# Iters. done: 76 [Current cost: -0.647322900390625]
# Iters. done: 77 [Current cost: -0.6477702148437501]
# Iters. done: 78 [Current cost: -0.6542087890625]
# Iters. done: 79 [Current cost: -0.6454140136718749]
# Iters. done: 80 [Current cost: -0.651915869140625]
# Iters. done: 81 [Current cost: -0.649894482421875]
# Iters. done: 82 [Current cost: -0.64606083984375]
# Iters. done: 83 [Current cost: -0.650897021484375]
# Iters. done: 84 [Current cost: -0.653230615234375]
# Iters. done: 85 [Current cost: -0.653003466796875]
# Iters. done: 86 [Current cost: -0.6517977539062499]
# Iters. done: 87 [Current cost: -0.642886474609375]
# Iters. done: 88 [Current cost: -0.6479435058593749]
# Iters. done: 89 [Current cost: -0.6564710937500001]
# Iters. done: 90 [Current cost: -0.656875244140625]
# Iters. done: 91 [Current cost: -0.64490029296875]
# Iters. done: 92 [Current cost: -0.6633989746093749]
# Iters. done: 93 [Current cost: -0.6529216796875]
# Iters. done: 94 [Current cost: -0.65248837890625]
# Iters. done: 95 [Current cost: -0.6461869140625001]
# Iters. done: 96 [Current cost: -0.6533357421875]
# Iters. done: 97 [Current cost: -0.6420374999999999]
# Iters. done: 98 [Current cost: -0.6464034179687499]
# Iters. done: 99 [Current cost: -0.646611181640625]
# Iters. done: 100 [Current cost: -0.6516937988281251]
# Iters. done: 101 [Current cost: -0.6403559570312499]
# Iters. done: 102 [Current cost: -0.645616845703125]
# Iters. done: 103 [Current cost: -0.645061767578125]
# Iters. done: 104 [Current cost: -0.6481019531250001]
# Iters. done: 105 [Current cost: -0.6439605468750002]
# Iters. done: 106 [Current cost: -0.6530009765625001]
# Iters. done: 107 [Current cost: -0.648650927734375]
# Iters. done: 108 [Current cost: -0.6492191406249999]
# Iters. done: 109 [Current cost: -0.6542846191406251]
# Iters. done: 110 [Current cost: -0.660615478515625]
# Iters. done: 111 [Current cost: -0.650779931640625]
# Iters. done: 112 [Current cost: -0.670004345703125]
# Iters. done: 113 [Current cost: -0.6616900878906249]
# Iters. done: 114 [Current cost: -0.6563555664062499]
# Iters. done: 115 [Current cost: -0.656898974609375]
# Iters. done: 116 [Current cost: -0.6473981933593751]
# Iters. done: 117 [Current cost: -0.6612360839843751]
# Iters. done: 118 [Current cost: -0.6522602539062501]
# Iters. done: 119 [Current cost: -0.6575182617187499]
# Iters. done: 120 [Current cost: -0.657427783203125]
# Iters. done: 121 [Current cost: -0.6497748535156251]
# Iters. done: 122 [Current cost: -0.6417287597656249]
# Iters. done: 123 [Current cost: -0.64247080078125]
# Iters. done: 124 [Current cost: -0.6491489257812502]
# Iters. done: 125 [Current cost: -0.64836513671875]
# Iters. done: 126 [Current cost: -0.6508725585937502]
# Iters. done: 127 [Current cost: -0.65604873046875]
# Iters. done: 128 [Current cost: -0.6587835937500001]
# Iters. done: 129 [Current cost: -0.6449489257812501]
# Iters. done: 130 [Current cost: -0.63774453125]
# Iters. done: 131 [Current cost: -0.649214208984375]
# Iters. done: 132 [Current cost: -0.6486768554687501]
# Iters. done: 133 [Current cost: -0.64706279296875]
# Iters. done: 134 [Current cost: -0.649840478515625]
# Iters. done: 135 [Current cost: -0.6533477539062501]
# Iters. done: 136 [Current cost: -0.6393367187500001]
# Iters. done: 137 [Current cost: -0.654448876953125]
# Iters. done: 138 [Current cost: -0.655722265625]
# Iters. done: 139 [Current cost: -0.64419052734375]
# Iters. done: 140 [Current cost: -0.6547398925781249]
# Iters. done: 141 [Current cost: -0.6488711425781251]
# Iters. done: 142 [Current cost: -0.6537927734375]
# Iters. done: 143 [Current cost: -0.652360791015625]
# Iters. done: 144 [Current cost: -0.654397119140625]
# Iters. done: 145 [Current cost: -0.6442619628906251]
# Iters. done: 146 [Current cost: -0.6559684570312501]
# Iters. done: 147 [Current cost: -0.65672763671875]
# Iters. done: 148 [Current cost: -0.650743212890625]
# Iters. done: 149 [Current cost: -0.6586681152343751]
# Iters. done: 150 [Current cost: -0.662778125]
# Iters. done: 151 [Current cost: -0.648045703125]
# Iters. done: 152 [Current cost: -0.6558246093750001]
# Iters. done: 153 [Current cost: -0.6451558105468751]
# Iters. done: 154 [Current cost: -0.6485580078125]
# Iters. done: 155 [Current cost: -0.6511102539062499]
# Iters. done: 156 [Current cost: -0.63195517578125]
# Iters. done: 157 [Current cost: -0.65154453125]
# Iters. done: 158 [Current cost: -0.635064111328125]
# Iters. done: 159 [Current cost: -0.66070576171875]
# Iters. done: 160 [Current cost: -0.6424314453125]
# Iters. done: 161 [Current cost: -0.6676613769531251]
# Iters. done: 162 [Current cost: -0.6683991210937501]
# Iters. done: 163 [Current cost: -0.6506014648437501]
# Iters. done: 164 [Current cost: -0.650457421875]
# Iters. done: 165 [Current cost: -0.645153466796875]
# Iters. done: 166 [Current cost: -0.647037451171875]
# Iters. done: 167 [Current cost: -0.636096875]
# Iters. done: 168 [Current cost: -0.660698583984375]
# Iters. done: 169 [Current cost: -0.649433447265625]
# Iters. done: 170 [Current cost: -0.658339208984375]

# %% [markdown]
# At the terminus of this routine we have a result in the standard SciPy `OptimizeResult` format.  From this we see that it took `nfev` number of cost function evaluations to obtain the solution vector of parameter angles (`x`) that, when plugged into the ansatz circuit, yield the approximate ground state solution we were looking for.

# %%
res
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: -0.658339208984375
#        x: [ 3.732e+00  5.841e+00 ...  4.854e+00  2.371e+00]
#     nfev: 170
#    maxcv: 0.0

# %% [markdown]
# ## Step 4: Post-process, return result in classical format

# %% [markdown]
# If the procedure terminates correctly, then the `prev_vector` and `iters` values in our `cost_history_dict` dictionary should be equal to the solution vector and total number of function evaluations, respectively.  This is easy to verify:

# %%
all(history["prev_vector"] == res.x)
# Out:
# True

# %%
history["iters"] == res.nfev
# Out:
# True

# %% [markdown]
# We can also now view the progress toward convergence as monitored by the cost history at each iteration:

# %%
fig, ax = plt.subplots()
ax.plot(range(history["iters"]), history["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
import qiskit

qiskit.version.get_version_info()
# Out:
# '1.1.1'

# %%
import qiskit_aer

qiskit_aer.version.get_version_info()
# Out:
# '0.14.2'
